# %% [markdown]
# # Circle detection (classical CV)
#
# - Goal: detect a circle and return a bounding box
# - No ML training
# - Later: segmentation + color + pixel count

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

print('OpenCV:', cv2.__version__)
