# %% [markdown]
# # Circle detection using classical computer vision
#
# This notebook detects a circular object in images using OpenCV.
# No training. Pure CV algorithms.

# %%
# Imports
import cv2
import numpy as np
import matplotlib.pyplot as plt
